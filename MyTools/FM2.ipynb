# %%
from osiloskop import Osiloskop

# Create an instance
osc = Osiloskop()

# Start streaming
osc.start_stream()

# Get microphone data
data = osc.get_data()

# Send data (if needed)
processed_data = osc.send_data()

# Visualize

osc.visualize()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from osiloskop import Osiloskop
#       3 # Create an instance
#       4 osc = Osiloskop()
#
# ImportError: cannot import name 'Osiloskop' from 'osiloskop' (/home/celik/github/AMKS_AUV_ATILAY/MyTools/osiloskop.py)

# %%
import math

def calculate_distance(SPL0, SPL, d0=1):
    return d0 * 10 ** ((SPL0 - SPL) / 20)

# Başlangıç ses basınç seviyesi (dB)
SPL0 = 100
# Hedef ses basınç seviyesi (dB)
SPL = 20

# Maksimum mesafeyi hesapla
max_distance = calculate_distance(SPL0, SPL)
print(f"Ses dalgasının havada gidebileceği maksimum mesafe: {max_distance:.2f} metre")
# Out:
# Ses dalgasının havada gidebileceği maksimum mesafe: 10000.00 metre

# %%
import matplotlib.pyplot as plt
import numpy as np

def calculate_distance(SPL0, SPL, d0=1):
    return d0 * 10 ** ((SPL0 - SPL) / 20)

# Başlangıç ses basınç seviyeleri (dB)
SPL0_values = np.linspace(60, 120, 100)
# Hedef ses basınç seviyesi (dB)
SPL = 20

# Maksimum mesafeleri hesapla
distances = [calculate_distance(SPL0, SPL) for SPL0 in SPL0_values]

# Grafik oluşturma
plt.figure(figsize=(10, 6))
plt.plot(SPL0_values, distances, label=f'Target SPL = {SPL} dB')

plt.xlabel('Initial Sound Pressure Level (SPL0) in dB')
plt.ylabel('Maximum Distance (meters)')
plt.title('Maximum Distance of Sound Wave in Air')
plt.legend()
plt.grid(True)

# Grafiği göster
plt.show()
